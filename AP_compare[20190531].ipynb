# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = np.zeros(1000)
for i in range(1000)
    data1[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190515-1/%s/v.npy' % "{0:05d}".format(i+4000))

# %% [markdown]
# # sodium channel (Ina)
# x 0.0 だけ波高が下がる

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190516-1/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190516-2/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190516-3/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190516-4/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()

# %% [markdown]
# # rapid delayed rectifier pottasium current (IKr)
# 弱めれば弱めるほどAPD延長。カリウムだからそりゃそうか。
# rapidっていう割には波形の変化が遅い。

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-1/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-2/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-3/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-4/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # slow delayed rectifier pottasium current (IKs)
# 活性抑制すると顕著にAPDが延長。ただx0.0のときは計算エラー？

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-5/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-6/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-7/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-8/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
# plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # T-type calcium channel (ICaT)
# 全く変化なし。こんなことある？

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-9/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-10/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-11/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190517-12/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # sodium current through L-type calcium channel (IlCaNa)
# ほとんど影響なし

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-1/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-2/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-3/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-4/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
# plt.xlim([800, 950])

# %% [markdown]
# # sodium pottasiuim pump (INaK)
# APDわずかに延長。

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-5/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-6/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-7/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-8/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # sodium calcium exchanger in myoplasm (Inaca)
# 静止膜電位が微妙に違う？

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-9/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-10/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-11/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-12/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # sodium calcium exchanger in subspace (Inacass)
# 変化なし

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-1/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-2/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-3/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-4/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # Time-independent pottasium channel (IKi)
# 静止膜電位の上昇。

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-5/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-6/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-7/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-8/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # Plateau pottasium channel (IKp)
# 変化なし

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-9/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-10/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-11/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-12/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # Pottasium current through L-type calcium channel (Ilcak)
# APD短縮

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-1/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-2/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-3/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-4/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # calcium current through L-type calcium channel (Ilca)
# APD短縮

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-5/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-6/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-7/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-8/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)

# %% [markdown]
# # Sarcolemmal calcium pump (Ipca)
# APD延長

# %%
data075 = np.zeros(1000)
data05 = np.zeros(1000)
data025 = np.zeros(1000)
data0 = np.zeros(1000)

for i in range(1000):
    data075[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-9/%s/v.npy' % "{0:05d}".format(i+4000))
    data05[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-10/%s/v.npy' % "{0:05d}".format(i+4000))
    data025[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-11/%s/v.npy' % "{0:05d}".format(i+4000))
    data0[i] = np.load('/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190529-12/%s/v.npy' % "{0:05d}".format(i+4000))

# %%
plt.plot(data1, label='x 1.0', linewidth=0.5)
plt.plot(data075, label='x 0.75', linewidth=0.5)
plt.plot(data05, label='x 0.5', linewidth=0.5)
plt.plot(data025, label='x 0.25', linewidth=0.5)
plt.plot(data0, label='x 0', linewidth=0.5)
plt.legend()
plt.xlim([800, 950])
# Out:
# (800, 950)
