# %%
#!/usr/local/bin/python

import os, sys
import json
import numpy as np
import matplotlib.pyplot as plt
import chainer
from chainer import cuda
from matplotlib import animation
from optparse import OptionParser

from elecpy.util.cmap_bipolar import bipolar
import elecpy.elecpy as elp

from matplotlib import animation, rc
from IPython.display import HTML

import time

# %matplotlib inline

# %%
from elecpy.cell.test import test

# %%
inactivation_rates = ['0.75', '0.5', '0.25', '0.0']

# %%
! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c

# %%
! cat ./elecpy/cell/luorudy/kernel.c | grep '_ilcana = '
# Out:
# _ilcana = 0.75*_ibarna*_fcasc*_fmode0*ltypeO*pow({Q10CAL_}, (temp-{temp_})/10.0);

# %%
! sed -i s/"_ilcana = "/"_ilcana = 0.75*"/ ./elecpy/cell/luorudy/kernel.c

# %%
! cat ./elecpy/cell/luorudy/kernel.c | grep '_ilcana = '
# Out:
# _ilcana = 0.75*0.75*_ibarna*_fcasc*_fmode0*ltypeO*pow({Q10CAL_}, (temp-{temp_})/10.0);

# %% [markdown]
# ## Ca-Na pump (Ilcana)

# %%
with open ('./elecpy/temp/pacing_params.json','r') as f:
    pacing_params = json.load(f)

# %%
for i, inactivation_rate in enumerate(inactivation_rates):
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
    if i == 0:
        ! sed -i s/"_ilcana = "/"_ilcana = 0.75*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 1:
        ! sed -i s/"_ilcana = "/"_ilcana = 0.5*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 2:
        ! sed -i s/"_ilcana = "/"_ilcana = 0.25*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 3:
        ! sed -i s/"_ilcana = "/"_ilcana = 0*"/ ./elecpy/cell/luorudy/kernel.c

    ! cat ./elecpy/cell/luorudy/kernel.c | grep '_ilcana = '
    
    test(pacing_params, '/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-%s'%(i+1))
    
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
# Out:
# _ilcana = 0.75*_ibarna*_fcasc*_fmode0*ltypeO*pow({Q10CAL_}, (temp-{temp_})/10.0);
# cell models pacing test.
# -------------100
# v: 16.4969387479
# it: 0.398250749897
# st: 0.0
# -------------200
# v: -87.1827780148
# it: 0.0416722994533
# st: 0.0
# -------------300
# v: 3.76085779641
# it: 0.673941508162
# st: 0.0
# -------------400
# v: -87.5493167193
# it: 0.0110745210989
# st: 0.0
# -------------500
# v: -4.38735385277
# it: 1.33785514735
# st: 0.0
# -------------600
# v: -87.5648362657
# it: 0.0111524086514
# st: 0.0
# -------------700
# v: -11.3952120597
# it: 2.19277735764
# st: 0.0
# -------------800
# v: -87.5704342638
# it: 0.0112547768479
# st: 0.0
# -------------900
# v: -20.2520256457
# it: 3.14133076661
# st: 0.0
# -------------1000
# v: -87.5631052782
# it: 0.0115797710462
# st: 0.0
# -------------1100
# v: -23.3415136387
# it: 3.40407688251
# st: 0.0
# -------------1200
# v: -87.5676801683
# it: 0.0115082395925
# st: 0.0
# -------------1300
# v: -27.2618326562
# ...

# %% [markdown]
# ## Na-K pump (Inak)

# %%
with open ('./elecpy/temp/pacing_params.json','r') as f:
    pacing_params = json.load(f)

# %%
! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c

# %%
for i, inactivation_rate in enumerate(inactivation_rates):
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
    if i == 0:
        ! sed -i s/"_inak = "/"_inak = 0.75*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 1:
        ! sed -i s/"_inak = "/"_inak = 0.5*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 2:
        ! sed -i s/"_inak = "/"_inak = 0.25*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 3:
        ! sed -i s/"_inak = "/"_inak = 0*"/ ./elecpy/cell/luorudy/kernel.c

    ! cat ./elecpy/cell/luorudy/kernel.c | grep '_inak = '
    
    test(pacing_params, '/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-%s'%(i+5))
    
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c

# %% [markdown]
# ## Na-Ca pump (Inaca)

# %%
with open ('./elecpy/temp/pacing_params.json','r') as f:
    pacing_params = json.load(f)

# %%
! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c

# %%
for i, inactivation_rate in enumerate(inactivation_rates):
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
    if i == 0:
        ! sed -i s/"_inaca = "/"_inaca = 0.75*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 1:
        ! sed -i s/"_inaca = "/"_inaca = 0.5*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 2:
        ! sed -i s/"_inaca = "/"_inaca = 0.25*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 3:
        ! sed -i s/"_inaca = "/"_inaca = 0*"/ ./elecpy/cell/luorudy/kernel.c

    ! cat ./elecpy/cell/luorudy/kernel.c | grep '_inaca = '
    
    test(pacing_params, '/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190520-%s'%(i+9))
    
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
