# %%
#!/usr/local/bin/python

import os, sys
import json
import numpy as np
import matplotlib.pyplot as plt
import chainer
from chainer import cuda
from matplotlib import animation
from optparse import OptionParser

from elecpy.util.cmap_bipolar import bipolar
import elecpy.elecpy as elp

from matplotlib import animation, rc
from IPython.display import HTML

import time

# %matplotlib inline

# %%
from elecpy.cell.test import test

# %%
inactivation_rates = ['0.75', '0.5', '0.25', '0.0']

# %%
! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c

# %%
! cat ./elecpy/cell/luorudy/kernel.c | grep '_ikp = '
# Out:
# double _ikp = _gkp*_kp*(_v-_ekp);

# %%
! sed -i s/"_ikp = "/"_ikp = 0.75*"/ ./elecpy/cell/luorudy/kernel.c

# %%
! cat ./elecpy/cell/luorudy/kernel.c | grep '_ikp = '
# Out:
# double _ikp = 0.75*_gkp*_kp*(_v-_ekp);

# %% [markdown]
# ## Na-Ca exchanger in subspace (Inacass)

# %%
with open ('./elecpy/temp/pacing_params.json','r') as f:
    pacing_params = json.load(f)

# %%
for i, inactivation_rate in enumerate(inactivation_rates):
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
    if i == 0:
        ! sed -i s/"_inacass = "/"_inacass = 0.75*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 1:
        ! sed -i s/"_inacass = "/"_inacass = 0.5*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 2:
        ! sed -i s/"_inacass = "/"_inacass = 0.25*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 3:
        ! sed -i s/"_inacass = "/"_inacass = 0*"/ ./elecpy/cell/luorudy/kernel.c

    ! cat ./elecpy/cell/luorudy/kernel.c | grep '_inacass = '
    
    test(pacing_params, '/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-%s'%(i+1))
    
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
# Out:
# _inacass = 0.75*(0.2*{c1_}*exp(({gammanaca_}-1)*_v*{frdy_}/({R_}*temp))*((exp(_v*{frdy_}/({R_}*temp))*_naiss*_naiss*_naiss*{cao_}-1.5*{nao_}*{nao_}*{nao_}*_caiss)/(1+{c2_}*exp(({gammanaca_}-1)*_v*{frdy_}/({R_}*temp))*(exp(_v*{frdy_}/({R_}*temp))*_naiss*_naiss*_naiss*{cao_}+{c3_}*{nao_}*{nao_}*{nao_}*_caiss))))*pow({Q10NACA_}, (temp-{temp_})/10.0);
# cell models pacing test.
# -------------100
# v: 16.9920574375
# it: 0.401512941471
# st: 0.0
# -------------200
# v: -87.3465556157
# it: 0.0438333726386
# st: 0.0
# -------------300
# v: 4.06611755306
# it: 0.672844769463
# st: 0.0
# -------------400
# v: -87.683507344
# it: 0.0108141344688
# st: 0.0
# -------------500
# v: -4.12672291369
# it: 1.35002592609
# st: 0.0
# -------------600
# v: -87.6941213233
# it: 0.0109567822615
# st: 0.0
# -------------700
# v: -11.2300303551
# it: 2.21816496407
# st: 0.0
# -------------800
# v: -87.6988315345
# it: 0.0110732018703
# st: 0.0
# -------------900
# v: -20.0808054954
# it: 3.17347450629
# ...

# %% [markdown]
# ## Time-independent pottasium channel (Iki)

# %%
with open ('./elecpy/temp/pacing_params.json','r') as f:
    pacing_params = json.load(f)

# %%
! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c

# %%
for i, inactivation_rate in enumerate(inactivation_rates):
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
    if i == 0:
        ! sed -i s/"_iki = "/"_iki = 0.75*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 1:
        ! sed -i s/"_iki = "/"_iki = 0.5*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 2:
        ! sed -i s/"_iki = "/"_iki = 0.25*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 3:
        ! sed -i s/"_iki = "/"_iki = 0*"/ ./elecpy/cell/luorudy/kernel.c

    ! cat ./elecpy/cell/luorudy/kernel.c | grep '_iki = '
    
    test(pacing_params, '/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-%s'%(i+5))
    
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
# Out:
# double _iki = 0.75*_gki*_kin*(_v-_eki);
# cell models pacing test.
# -------------100
# v: 16.968227006
# it: 0.400715615199
# st: 0.0
# -------------200
# v: -85.3205105382
# it: 0.153198062297
# st: 0.0
# -------------300
# v: 3.85526295231
# it: 0.677782640526
# st: 0.0
# -------------400
# v: -86.3504238059
# it: 0.0128471604758
# st: 0.0
# -------------500
# v: -4.51977576022
# it: 1.38169840891
# st: 0.0
# -------------600
# v: -86.3539048123
# it: 0.0133533719424
# st: 0.0
# -------------700
# v: -11.8872168196
# it: 2.29452160245
# st: 0.0
# -------------800
# v: -86.3575492102
# it: 0.0135955880998
# st: 0.0
# -------------900
# v: -21.3619136437
# it: 3.29132433318
# st: 0.0
# -------------1000
# v: -86.3422654919
# it: 0.0141013437689
# st: 0.0
# -------------1100
# v: -24.618139017
# it: 3.5414104179
# st: 0.0
# -------------1200
# v: -86.3472255174
# it: 0.0140336417651
# st: 0.0
# -------------1300
# v: -28.7400323725
# it: 3.73901559934
# st: 0.0
# -------------1400
# ...

# %% [markdown]
# ## Plateau pottasium channel (Ikp)

# %%
with open ('./elecpy/temp/pacing_params.json','r') as f:
    pacing_params = json.load(f)

# %%
! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c

# %%
for i, inactivation_rate in enumerate(inactivation_rates):
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
    if i == 0:
        ! sed -i s/"_ikp = "/"_ikp = 0.75*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 1:
        ! sed -i s/"_ikp = "/"_ikp = 0.5*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 2:
        ! sed -i s/"_ikp = "/"_ikp = 0.25*"/ ./elecpy/cell/luorudy/kernel.c
    elif i == 3:
        ! sed -i s/"_ikp = "/"_ikp = 0*"/ ./elecpy/cell/luorudy/kernel.c

    ! cat ./elecpy/cell/luorudy/kernel.c | grep '_ikp = '
    
    test(pacing_params, '/mnt/Omer/Project/11.HeterogeneityControl/SimulationData/0D/20190524-%s'%(i+9))
    
    ! cp ./elecpy/cell/luorudy/kernel.c.bak ./elecpy/cell/luorudy/kernel.c
# Out:
# double _ikp = 0.75*_gkp*_kp*(_v-_ekp);
# cell models pacing test.
# -------------100
# v: 17.0325450046
# it: 0.401773413113
# st: 0.0
# -------------200
# v: -87.1365968397
# it: 0.0475799610988
# st: 0.0
# -------------300
# v: 4.04415138957
# it: 0.675229496713
# st: 0.0
# -------------400
# v: -87.5297735737
# it: 0.0112540244131
# st: 0.0
# -------------500
# v: -4.04715309688
# it: 1.34278136405
# st: 0.0
# -------------600
# v: -87.5433066852
# it: 0.0113911555341
# st: 0.0
# -------------700
# v: -11.0471346275
# it: 2.19500436397
# st: 0.0
# -------------800
# v: -87.5481830596
# it: 0.0115169839921
# st: 0.0
# -------------900
# v: -19.983967899
# it: 3.16199185677
# st: 0.0
# -------------1000
# v: -87.5430167521
# it: 0.0117958526601
# st: 0.0
# -------------1100
# v: -23.0392875487
# it: 3.42947090627
# st: 0.0
# -------------1200
# v: -87.5477829315
# it: 0.0117224670229
# st: 0.0
# -------------1300
# v: -26.9889231465
# it: 3.67073056686
# st: 0.0
# -------------1400
# ...
